# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT DATASET AND LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
# %matplotlib inline

# %%
from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
# import the csv files using pandas 
df = pd.read_csv('university_admission.csv')

# %%
# Let's explore the dataframe
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# ..               ...
# 495             0.87
# 496             0.96
# 497             0.93
# 498             0.73
# 499             0.84
#
# [500 rows x 8 columns]

# %%
df.head(5)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
df.tail(10)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 490        307          105                  2  2.5   4.5  8.12         1
# 491        297           99                  4  3.0   3.5  7.81         0
# 492        298          101                  4  2.5   4.5  7.69         1
# 493        300           95                  2  3.0   1.5  8.22         1
# 494        301           99                  3  2.5   2.0  8.45         1
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 490             0.67
# 491             0.54
# 492             0.53
# 493             0.62
# 494             0.68
# 495             0.87
# 496             0.96
# 497             0.93
# 498             0.73
# 499             0.84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# 50%      8.560000    1.000000          0.72000
# 75%      9.040000    1.000000          0.82000
# max      9.920000    1.000000          0.97000

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **Calculate the average, minimum and maximum chances of admission using two different techniques**

# %%
df.max()
# Out:
# GRE Score            340.00
# TOEFL Score          120.00
# University Rating      5.00
# SOP                    5.00
# LOR                    5.00
# CGPA                   9.92
# Research               1.00
# Chance of Admit        0.97
# dtype: float64

# %% [markdown]
# # TASK #3: PERFORM DATA VISUALIZATION & PREPARE THE DATA FOR MODEL TRAINING

# %%
# The plotly Python package empowers anyone to create, manipulate and render graphical figures.
# The figures are represented by data structures referred to as figures. 
# The rendering process uses the Plotly.js JavaScript library under the hood but you never need to use Java directly. 
# Figures can be represented in Python either as dictionaries or as instances of the plotly.graph_objects

# Note: 
# Plotly Express is the recommended entry-point into the plotly package 
# PLotly Express is the high-level plotly.express module that consists of Python functions which return fully-populated plotly.graph_objects.Figure objects. 
# plotly.express module contains functions that can create interactive figures using a very few lines of code
# Plotly Express is refered to as px. 
# Plotly Express is a built-in part of the plotly library 
# Plotly Express function uses graph objects internally and returns a plotly.graph_objects.Figure instance.
# check out the documentation here: https://plotly.com/python/plotly-express/ 

import plotly.express as px

# Let's add a fourth variable "SOP" as the size 
fig = px.scatter(df, x = "GRE Score", y = "Chance of Admit", color = "University Rating", size= 'SOP')
fig.show()
# Out:
# <div>                            <div id="04def226-205b-4555-baee-1f8ec4744970" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04def226-205b-4555-baee-1f8ec4744970")) {                    Plotly.newPlot(                        "04def226-205b-4555-baee-1f8ec4744970",                        [{"hovertemplate": "GRE Score=%{x}<br>Chance of Admit=%{y}<br>SOP=%{marker.size}<br>University Rating=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [4, 4, 3, 3, 2, 5, 3, 2, 1, 3, 3, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 4, 5, 5, 5, 5, 5, 2, 1, 2, 2, 3, 4, 5, 5, 5, 2, 1, 1, 2, 3, 2, 2, 4, 5, 5, 5, 5, 3, 4, 3, 2, 4, 4, 3, 3, 3, 2, 1, 2, 2, 3, 2, 2, 3, 4, 3, 2, 3, 4, 5, 5, 5, 4, 3, 2, 3, 2, 2, 1, 3, 4, 5, 5, 5, 4, 3, 2, 3, 4, 2, 3, 2, 2, 3, 4, 2, 3, 4, 3, 3, 2, 2, 2, 3, 3, 4, 4, 5, 5, 5, 4, 3, 2, 3, 4, 3, 4, 2, 5, 5, 5, 4, 3, 4, 3, 3, 3, 3, 5, 5, 5, 5, 5, 5, 4, 3, 2, 2, 1, 2, 2, 5, 4, 2, 2, 3, 3, 4, 2, 4, 5, 5, 3, 3, 3, 3, 2, 2, 1, 1, 1, 3, 3, 4, 5, 3, 3, 2, 2, 2, 5, 4, 4, 4, 4, 4, 3, 3, 3, 3, 2, 2, 3, 2, 4, 3, 5, 5, 5, 5, 5, 5, 5, 3, 2, 2, 2, 3, 3, 3, 2, 5, 5, 3, 2, 2, 3, 2, 3, 4, 4, 4, 5, 4, 5, 4, 4, 4, 3, 3, 3, 4, 2, 2, 2, 2, 2, 3, 4, 3, 3, 2, 2, 5, 5, 4, 5, 3, 1, 1, 2, 3, 3, 2, 4, 3, 2, 3, 3, 3, 2, 2, 4, 4, 4, 3, 3, 4, 4, 5, 3, 2, 3, 2, 3, 2, 3, 4, 4, 2, 2, 1, 1, 1, 3, 5, 2, 2, 2, 3, 3, 3, 3, 4, 5, 5, 5, 4, 3, 2, 2, 2, 1, 2, 2, 3, 3, 3, 3, 2, 2, 2, 3, 2, 3, 3, 4, 3, 4, 3, 4, 4, 3, 2, 2, 2, 1, 3, 4, 3, 3, 2, 2, 3, 3, 3, 2, 4, 2, 3, 2, 3, 3, 4, 4, 3, 5, 5, 5, 3, 3, 3, 2, 2, 1, 2, 1, 1, 3, 3, 4, 2, 3, 2, 2, 3, 2, 2, 2, 3, 4, 5, 2, 3, 4, 3, 1, 1, 1, 2, 3, 4, 3, 2, 2, 2, 1, 1, 1, 3, 3, 4, 3, 4, 5, 2, 2, 2, 3, 2, 3, 4, 2, 4, 3, 3, 4, 3, 4, 2, 2, 3, 4, 3, 3, 4, 3, 3, 1, 1, 2, 4, 3, 4, 4, 3, 3, 2, 2, 3, 3, 4, 5, 5, 5, 3, 3, 2, 5, 3, 2, 4, 4, 3, 2, 1, 1, 1, 2, 2, 1, 4, 5, 5, 5, 4, 3, 2, 3, 4, 4, 4, 3, 2, 2, 2, 1, 1, 4, 4, 3, 4, 3, 2, 4, 4, 5, 4, 4, 5, 3, 4, 2, 4, 3, 3, 4, 3, 4, 3, 4, 4, 5, 3, 2, 3, 4, 3, 3, 2, 4, 4, 2, 3, 5, 5, 5, 4, 4], "coloraxis": "coloraxis", "size": [4.5, 4.0, 3.0, 3.5, 2.0, 4.5, 3.0, 3.0, 2.0, 3.5, 3.5, 4.0, 4.0, 4.0, 3.5, 3.5, 4.0, 4.0, 4.0, 3.5, 3.0, 3.0, 5.0, 5.0, 4.0, 4.5, 4.5, 1.5, 2.0, 1.5, 3.0, 4.0, 3.0, 4.0, 4.0, 5.0, 4.0, 1.0, 3.0, 4.0, 3.5, 2.5, 2.5, 4.5, 4.5, 5.0, 4.0, 4.5, 3.5, 3.0, 2.5, 1.5, 4.0, 4.0, 3.0, 3.0, 2.0, 4.0, 3.0, 2.0, 3.0, 4.0, 3.0, 4.0, 3.0, 3.5, 3.0, 3.5, 3.5, 4.5, 5.0, 5.0, 5.0, 4.5, 3.0, 2.0, 3.0, 3.0, 3.0, 1.5, 2.0, 5.0, 5.0, 4.0, 4.5, 4.5, 4.5, 3.5, 4.5, 4.5, 4.0, 5.0, 4.0, 3.0, 2.0, 1.5, 3.0, 4.0, 5.0, 4.0, 3.5, 2.5, 4.0, 4.5, 3.5, 4.0, 4.5, 3.5, 5.0, 5.0, 3.0, 4.0, 3.5, 4.0, 3.5, 4.5, 4.0, 2.0, 3.0, 3.0, 5.0, 4.5, 1.5, 3.5, 2.5, 2.0, 4.0, 2.5, 3.5, 5.0, 4.0, 5.0, 3.5, 4.0, 4.0, 3.5, 5.0, 1.5, 4.5, 3.5, 4.0, 4.5, 4.0, 4.5, 3.0, 2.0, 2.0, 3.0, 4.0, 3.5, 4.0, 5.0, 5.0, 3.0, 3.0, 3.0, 2.0, 2.0, 2.0, 1.5, 1.5, 1.5, 3.0, 3.5, 4.5, 4.5, 3.5, 2.0, 2.0, 2.5, 2.5, 4.0, 4.0, 4.0, 4.0, 4.5, 4.5, 3.5, 2.5, 3.0, 3.5, 2.5, 3.0, 4.0, 2.5, 4.5, 3.5, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.5, 3.5, 3.0, 3.0, 3.5, 4.5, 4.0, 2.5, 3.5, 4.5, 4.0, 3.5, 2.5, 3.5, 3.5, 3.0, 3.5, 4.5, 5.0, 5.0, 5.0, 4.5, 5.0, 4.5, 4.0, 3.0, 3.5, 4.0, 3.5, 4.5, 3.0, 3.0, 2.5, 3.5, 3.5, 4.0, 3.0, 4.0, 3.5, 2.5, 2.5, 5.0, 4.5, 4.0, 4.5, 2.0, 1.5, 2.5, 2.5, 3.5, 3.5, 2.5, 4.0, 3.0, 2.5, 3.5, 3.5, 3.0, 2.5, 2.5, 4.5, 4.0, 4.0, 4.0, 4.0, 5.0, 5.0, 5.0, 3.5, 2.5, 2.5, 3.0, 2.5, 2.0, 3.0, 4.5, 4.5, 2.5, 1.5, 1.5, 1.0, 2.0, 3.5, 5.0, 2.5, 3.0, 3.0, 4.5, 4.0, 4.0, 2.5, 5.0, 4.0, 4.5, 5.0, 5.0, 4.0, 2.5, 1.5, 1.0, 3.5, 2.5, 3.0, 3.5, 4.0, 4.5, 3.0, 2.5, 2.5, 3.0, 3.5, 2.5, 3.5, 4.0, 4.0, 3.5, 3.5, 3.0, 4.5, 4.5, 3.5, 3.0, 2.5, 1.5, 1.0, 2.5, 3.5, 4.0, 4.0, 2.5, 2.0, 3.0, 3.5, 2.0, 2.5, 4.0, 2.5, 3.5, 3.0, 3.5, 3.0, 4.5, 4.0, 3.0, 5.0, 4.0, 3.5, 3.0, 3.5, 3.0, 2.5, 1.5, 1.5, 1.5, 1.0, 2.0, 2.5, 3.0, 3.5, ...

# %%
sns.pairplot(df);

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(df.corr(), annot = True);

# %%
y = df['Chance of Admit']

# %%
df = df.drop(['Chance of Admit'], axis = 1)

# %%
X = df

# %%
X.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (400, 7)

# %%
X_test.shape
# Out:
# (100, 7)

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
# - **Modify the SOP column to make the bubble size variations more prominent**

# %% [markdown]
# # TASK #4: TRAIN AN XG-BOOST ALGORITHM WITHOUT OPTIMIZATION

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\administrator\appdata\roaming\python\python37\site-packages (1.4.2)
# Requirement already satisfied: numpy in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in c:\users\administrator\appdata\roaming\python\python37\site-packages (from xgboost) (1.6.3)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Train an XGBoost regressor model 

import xgboost as xgb

model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 1, max_depth = 20, n_estimators = 500)

model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=1, max_delta_step=0, max_depth=20,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=2, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# predict the score of the trained model using the testing dataset

result = model.score(X_test, y_test)
print("Accuracy : {}".format(result))
# Out:
# Accuracy : 0.613686828327755

# %%
# make predictions on the test data
y_predict = model.predict(X_test)

# %%
y_test
# Out:
# 258    0.77
# 91     0.38
# 14     0.61
# 361    0.93
# 178    0.72
#        ...
# 292    0.56
# 384    0.96
# 99     0.79
# 73     0.84
# 194    0.77
# Name: Chance of Admit, Length: 100, dtype: float64

# %%
y_predict
# Out:
# array([0.78412527, 0.56670547, 0.70461386, 0.9449485 , 0.58717096,
#        0.71139306, 0.7663951 , 0.8651134 , 0.5706633 , 0.6621922 ,
#        0.9350442 , 0.6436815 , 0.63304675, 0.62672997, 0.87167203,
#        0.69545335, 0.6971975 , 0.71244985, 0.7499774 , 0.6811551 ,
#        0.67802083, 0.7976576 , 0.80366987, 0.62483937, 0.5087753 ,
#        0.75932616, 0.90721935, 0.45689622, 0.82265514, 0.8486458 ,
#        0.6712446 , 0.5933033 , 0.776041  , 0.5544938 , 0.7314156 ,
#        0.89471847, 0.7467284 , 0.6246249 , 0.9695215 , 0.6259989 ,
#        0.94539756, 0.71959823, 0.8122817 , 0.52849025, 0.6617514 ,
#        0.630865  , 0.6535748 , 0.63012797, 0.7787747 , 0.47830915,
#        0.67688   , 0.6735218 , 0.6869753 , 0.7762193 , 0.56651855,
#        0.677397  , 0.7902223 , 0.6816655 , 0.7981286 , 0.6932467 ,
#        0.892134  , 0.6871051 , 0.9094984 , 0.7757269 , 0.78348273,
#        0.49860695, 0.86480933, 0.78591716, 0.74266505, 0.876336  ,
#        0.74338686, 0.78758126, 0.7724435 , 0.7982334 , 0.5562456 ,
#        0.9296272 , 0.6786951 , 0.7679744 , 0.8859006 , 0.5595049 ,
#        0.70226365, 0.70139766, 0.7769297 , 0.9600124 , 0.8098507 ,
#        0.7541436 , 0.9599331 , 0.59259194, 0.62948024, 0.8206328 ,
#        0.5396214 , 0.46109504, 0.681217  , 0.53456855, 0.9458111 ,
#        0.46838468, 0.95466805, 0.8268374 , 0.71582127, 0.67284465],
#       dtype=float32)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
k = X_test.shape[1]
n = len(X_test)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 0.089
# MSE = 0.007864779884279702
# MAE = 0.062246599292755125
# R2 = 0.613686828327755

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Retrain the model with less 'max_depth' and comment on the results**

# %% [markdown]
# # TASK #5: PERFORM HYPERPARAMETERS OPTIMIZATION USING GRIDSEARCH

# %% [markdown]
# - GridSearch performs exhaustive search over a specified list of parameters.
# - You provide the algorithm with the hyperparameters you’d like to experiment with and the values we want to try out.
# - Note that you will have the following number of combinations: 3 * 3 * 3 * 2 = 54.
# - We will run each combination 5 times since we set the crossvalidation = 5.
# - Total number of runs = 54 * 5 = 270

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters_grid = { 'max_depth': [3, 6, 10], 
                   'learning_rate': [0.01, 0.05, 0.1],
                   'n_estimators': [100, 500, 1000],
                   'colsample_bytree': [0.3, 0.7]}

# %%
import xgboost as xgb

# %%
model = xgb.XGBRegressor()

# %%
# Note that we used the "neg_mean_squared_error" since GridSearchCV() ranks all the algorithms (estimators) 
# and specifies which one is the best. We are trying to minimize the error.  
xgb_gridsearch = GridSearchCV(estimator = model, 
                              param_grid = parameters_grid, 
                              scoring = 'neg_mean_squared_error',  
                              cv = 5, 
                              verbose = 5)

# %%
xgb_gridsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.016, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.014, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.003, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.002, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.005, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.002, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.016, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.014, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.002, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.005, total=   0.4s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.002, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.005, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.016, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.014, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.012, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.002, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.005, total=   1.6s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.004, total=   1.7s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.005, total=   1.6s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.003, total=   1.6s
# [CV] colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.005, total=   1.7s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.002, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.005, total=   0.4s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.005, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.005, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.005, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.003, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.002, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.003, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.005, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.005, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.005, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.005, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.003, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.005, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.0s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.005, total=   0.0s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.003, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.006, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.005, total=   0.4s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.006, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.006, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.003, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.4s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.003, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.005, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.006, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.006, total=   0.8s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.005, total=   0.7s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.005, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.013, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.002, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500, score=-0.005, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.002, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.015, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.013, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.012, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100, score=-0.014, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.002, total=   1.0s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.004, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.003, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000, score=-0.006, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.012, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.015, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.013, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.012, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, score=-0.014, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   1.3s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.004, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.003, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, score=-0.005, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.004, total=   2.4s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.004, total=   2.5s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.004, total=   2.2s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.003, total=   2.4s
# [CV] colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, score=-0.005, total=   2.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.002, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500, score=-0.006, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000, score=-0.006, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.003, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500, score=-0.006, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.005, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.004, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.003, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, score=-0.006, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.002, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100, score=-0.006, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500, score=-0.006, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.004, total=   0.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.003, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000, score=-0.006, total=   0.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.002, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-0.005, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.005, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.004, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.005, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.003, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-0.006, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.003, total=   0.7s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000, score=-0.007, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.004, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.003, total=   0.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, score=-0.006, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.005, total=   0.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.003, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500, score=-0.006, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.005, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000, score=-0.006, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.004, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.003, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-0.006, total=   0.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.004, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.003, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-0.006, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.004, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.004, total=   0.5s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.003, total=   0.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000, score=-0.006, total=   0.6s
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed:  2.2min finished
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'colsample_bytree': [0.3, 0.7],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 6, 10],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='neg_mean_squared_error', verbose=5)

# %%
xgb_gridsearch.best_params_
# Out:
# {'colsample_bytree': 0.3,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'n_estimators': 500}

# %%
xgb_gridsearch.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=2, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predict = xgb_gridsearch.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
k = X_test.shape[1]
n = len(X_test)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 0.074
# MSE = 0.0054297962523599695
# MAE = 0.048047455978393556
# R2 = 0.7332917331893822

# %% [markdown]
# # TASK #6: PERFORM HYPERPARAMETERS OPTIMIZATION USING RANDOM SEARCH

# %% [markdown]
# - Grid search works great if the number of combinations are limited.
# - In scenarios when the search space is large, RandomizedSearchCV is preferred.
# - The algorithm works by evaluating a select few numbers of random combinations.
# - You have the freedom and control over the number of iterations.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Define the grid of hyperparameters to search

# you can choose which booster you'd like to choose: 
# Two options are available: gbtree, gblinear
# gbtree uses tree based models while gblinear uses linear functions

grid = {
    'n_estimators': [100, 500, 700],
    'max_depth': [2, 3, 5],
    'learning_rate': [0.1, 0.5, 1],
    'min_child_weight': [1, 2, 3]  
            }


import xgboost as xgb
model = xgb.XGBRegressor()

# Set up the random search 
random_cv = RandomizedSearchCV(estimator = model,
                               param_distributions = grid,
                               cv = 5, 
                               n_iter = 50,
                               scoring = 'neg_mean_absolute_error',
                               verbose = 5, 
                               return_train_score = True)
random_cv.fit(X_train, y_train)

random_cv.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.049), total=   0.2s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.050), total=   0.2s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.053), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.042), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.060), total=   0.1s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.049), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.050), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.053), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.042), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.060), total=   0.2s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.008, test=-0.049), total=   0.4s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.009, test=-0.047), total=   0.4s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.008, test=-0.049), total=   0.5s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.010, test=-0.044), total=   0.5s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.008, test=-0.059), total=   0.4s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.002, test=-0.055), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.053), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.068), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.067), total=   0.2s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.052), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.046), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.022, test=-0.055), total=   0.1s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.057), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.064), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.052), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.055), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.050), total=   0.3s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.049), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.066), total=   0.2s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.057), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.064), total=   0.1s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.056), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.059), total=   0.4s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.052), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.064), total=   0.3s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.055), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.060), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.053), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.005, test=-0.055), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.069), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.009, test=-0.049), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.009, test=-0.053), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.010, test=-0.049), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.010, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.010, test=-0.064), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.012, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.013, test=-0.045), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.014, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.014, test=-0.036), total=   0.2s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.011, test=-0.056), total=   0.1s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1, score=(train=-0.010, test=-0.045), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1, score=(train=-0.011, test=-0.045), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1, score=(train=-0.011, test=-0.048), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1, score=(train=-0.011, test=-0.042), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=3, learning_rate=0.1, score=(train=-0.009, test=-0.060), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.025, test=-0.045), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.047), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.049), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.025, test=-0.040), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.023, test=-0.054), total=   0.2s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.024, test=-0.047), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.050), total=   0.0s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.052), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.024, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.056), total=   0.1s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.061), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.055), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.070), total=   0.2s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.050), total=   0.4s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.5s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.003, test=-0.043), total=   0.9s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.062), total=   0.5s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.056), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.053), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.057), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.007, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.063), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.061), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.057), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.063), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.058), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.064), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.048), total=   0.4s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.043), total=   0.5s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.062), total=   0.5s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.033, test=-0.044), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.032, test=-0.044), total=   0.0s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.032, test=-0.046), total=   0.0s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.035, test=-0.034), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=0.1, score=(train=-0.032, test=-0.051), total=   0.0s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.049), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.050), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.063), total=   0.1s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.050), total=   0.4s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.003, test=-0.043), total=   0.4s
# [CV] n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=3, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.062), total=   0.3s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.018, test=-0.055), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.017, test=-0.054), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.017, test=-0.055), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.017, test=-0.050), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.016, test=-0.061), total=   0.1s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.003, test=-0.060), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.063), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.003, test=-0.056), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=1, score=(train=-0.003, test=-0.065), total=   0.2s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.046), total=   0.4s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.046), total=   0.4s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.049), total=   0.4s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.040), total=   0.4s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.1, score=(train=-0.002, test=-0.058), total=   0.4s
# [CV] n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.049), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.050), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.063), total=   0.2s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1, score=(train=-0.027, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1, score=(train=-0.026, test=-0.045), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1, score=(train=-0.027, test=-0.046), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1, score=(train=-0.028, test=-0.034), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=3, learning_rate=0.1, score=(train=-0.025, test=-0.054), total=   0.1s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.044), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.047), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.050), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.025, test=-0.041), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.023, test=-0.054), total=   0.2s
# [CV] n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.003, test=-0.055), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.053), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.068), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.054), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.004, test=-0.067), total=   0.1s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.051), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.048), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.051), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.049), total=   0.2s
# [CV] n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.061), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.052), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.055), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.050), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.049), total=   0.3s
# [CV] n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=2, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.066), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.060), total=   0.2s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.059), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.064), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.065), total=   0.3s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.018, test=-0.052), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.019, test=-0.058), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.018, test=-0.058), total=   0.0s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.018, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.018, test=-0.058), total=   0.0s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.049), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.050), total=   0.2s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.048), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.063), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1, score=(train=-0.023, test=-0.044), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.047), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1, score=(train=-0.024, test=-0.050), total=   0.3s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1, score=(train=-0.025, test=-0.041), total=   0.2s
# [CV] n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=500, min_child_weight=1, max_depth=2, learning_rate=0.1, score=(train=-0.023, test=-0.055), total=   0.2s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.002, test=-0.055), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.053), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.068), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=1, score=(train=-0.001, test=-0.067), total=   0.3s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.003, test=-0.061), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.056), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.064), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.057), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=1, score=(train=-0.004, test=-0.064), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.009, test=-0.054), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.009, test=-0.052), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.009, test=-0.057), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.010, test=-0.053), total=   0.3s
# [CV] n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=2, max_depth=2, learning_rate=0.5, score=(train=-0.009, test=-0.062), total=   0.2s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.033, test=-0.045), total=   0.0s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.032, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.033, test=-0.045), total=   0.0s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.035, test=-0.035), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=2, learning_rate=0.1, score=(train=-0.031, test=-0.051), total=   0.0s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.058), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.003, test=-0.060), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.066), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.053), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=2, learning_rate=1, score=(train=-0.002, test=-0.062), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.2s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.057), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.056), total=   0.3s
# [CV] n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1
# [CV]  n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.064), total=   0.3s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.022, test=-0.047), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.052), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.023, test=-0.045), total=   0.1s
# [CV] n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.022, test=-0.057), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.057), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.059), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.058), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.070), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.051), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.002, test=-0.048), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.051), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.049), total=   0.1s
# [CV] n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5
# [CV]  n_estimators=100, min_child_weight=2, max_depth=5, learning_rate=0.5, score=(train=-0.001, test=-0.061), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.027, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.026, test=-0.043), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.027, test=-0.045), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.029, test=-0.034), total=   0.1s
# [CV] n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1
# [CV]  n_estimators=100, min_child_weight=3, max_depth=3, learning_rate=0.1, score=(train=-0.025, test=-0.054), total=   0.1s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.049), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.056), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.046), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.063), total=   0.3s
# [CV] n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.057), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.054), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.059), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.058), total=   0.2s
# [CV] n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1
# [CV]  n_estimators=500, min_child_weight=2, max_depth=5, learning_rate=1, score=(train=-0.001, test=-0.070), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.053), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.057), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.052), total=   0.2s
# [CV] n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.051), total=   0.3s
# [CV] n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5
# [CV]  n_estimators=500, min_child_weight=3, max_depth=3, learning_rate=0.5, score=(train=-0.002, test=-0.065), total=   0.2s
# [CV] n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.054), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.050), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.057), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.052), total=   0.3s
# [CV] n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5
# [CV]  n_estimators=700, min_child_weight=1, max_depth=2, learning_rate=0.5, score=(train=-0.006, test=-0.062), total=   0.3s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:   53.8s finished
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=2,
#              min_child_weight=3, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=2, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predict = random_cv.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
k = X_test.shape[1]
n = len(X_test)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 0.072
# MSE = 0.0052113431422246915
# MAE = 0.047576700031757346
# R2 = 0.744022016182643

# %% [markdown]
# # TASK #7: PERFORM HYPERPARAMETERS OPTIMIZATION USING BAYESIAN OPTIMIZATION

# %% [markdown]
# - Bayesian optimization overcomes the drawbacks of random search algorithms by exploring search spaces in a more efficient manner.
# - If a region in the search space appears to be promising (i.e.: resulted in a small error), this region should be explored more which increases the chances of achieving better performance!
# - You will need to specify the parameters search space.

# %%
# Let's install a library called Scikit-Optimize (Skopt) which is used to perform bayesian optimization 
# BayesSearchCV class is used in a similar fashion to GridSearchCV
# You secify the search space as a distribution instead of discrete values

! pip install scikit-optimize
from skopt import BayesSearchCV
import xgboost as xgb
# Out:
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-optimize in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (0.9.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from scikit-optimize) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from scikit-optimize) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: pyaml>=16.9 in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\administrator\appdata\roaming\python\python37\site-packages (from scikit-optimize) (1.6.3)
# Requirement already satisfied: PyYAML in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)

# %%
model = xgb.XGBRegressor()

# %%
search_space = {
    "learning_rate": (0.01, 1.0, "log-uniform"),
    "max_depth": (1, 50),
    "n_estimators": (5, 500),
}

# %%
xgb_bayes_search = BayesSearchCV(model, 
                               search_space, 
                               n_iter = 50, 
                               scoring = 'neg_mean_absolute_error', 
                               cv = 5)

# %%
result = xgb_bayes_search.fit(X_train, y_train)

# %%
y_predict = xgb_bayes_search.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
k = X_test.shape[1]
n = len(X_test)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 0.067
# MSE = 0.0044787398319759
# MAE = 0.04886828186511992
# R2 = 0.77329482486016

# %% [markdown]
# # FINAL CAPSTONE PROJECT

# %% [markdown]
# Using the used car prices dataset included in the course package, perform the following:
# 1. Load the “used_car_price.csv” dataset
# 3. Split the data into 75% for training and 25% for testing
# 4. Train an XG-Boost model in Scikit-Learn
# 5. Assess trained XG-Boost model performance using RMSE and R2
# 6. Perform hyperparameters optimization using GridSearch, choose any reasonable values for max_depth, learning_rate, n_estimators, and colsample_bytree. Use 5 cross validation folds.
# 7. Perform hyperparameters optimization using RandomSearch, choose any reasonable values for max_depth, learning_rate, n_estimators, and colsample_bytree. Use 5 cross validation folds and 100 iterations.
# 8. Compare the optimization strategies using RMSE and R2. Feel free to introduce any additional optimization strategy. Comment on your resuk

# %% [markdown]
# # FINAL CAPSTONE PROJECT SOLUTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the CSV file 
car_df = pd.read_csv("used_car_price.csv")

# %%
# Load the top 6 instances
car_df.head(6)
# Out:
#     Make                    Model   Type Origin DriveTrain   MSRP  EngineSize  \
# 0  Acura                      MDX    SUV   Asia        All  36945         3.5
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  23820         2.0
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  26990         2.4
# 3  Acura                   TL 4dr  Sedan   Asia      Front  33195         3.2
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  43755         3.5
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  46100         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0          6         265        17           23    4451        106     189
# 1          4         200        24           31    2778        101     172
# 2          4         200        22           29    3230        105     183
# 3          6         270        20           28    3575        108     186
# 4          6         225        18           24    3880        115     197
# 5          6         225        18           24    3893        115     197

# %%
# Perform One-Hot Encoding for "Make", "Model", "Type", "Origin", and "DriveTrain"
car_df = pd.get_dummies(car_df, columns=["Make", "Model", "Type", "Origin", "DriveTrain"])

# %%
# Feeding input features to X and output (MSRP) to y
X = car_df.drop("MSRP", axis = 1)
y = car_df["MSRP"]

# %%
X = np.array(X)

# %%
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = 0.25)

# %%
X_train
# Out:
# array([[  3.5,   6. , 200. , ...,   0. ,   1. ,   0. ],
#        [  2.2,   4. , 140. , ...,   0. ,   1. ,   0. ],
#        [  4.4,   8. , 325. , ...,   0. ,   0. ,   1. ],
#        ...,
#        [  5. ,   8. , 302. , ...,   0. ,   0. ,   1. ],
#        [  4.2,   6. , 275. , ...,   0. ,   1. ,   0. ],
#        [  5.7,   8. , 350. , ...,   0. ,   0. ,   1. ]])

# %%
X_test
# Out:
# array([[  4.7,   8. , 235. , ...,   1. ,   0. ,   0. ],
#        [  3.5,   6. , 255. , ...,   0. ,   1. ,   0. ],
#        [  2.2,   4. , 143. , ...,   1. ,   0. ,   0. ],
#        ...,
#        [  2.5,   6. , 165. , ...,   1. ,   0. ,   0. ],
#        [  5. ,   8. , 302. , ...,   1. ,   0. ,   0. ],
#        [  1.8,   4. , 124. , ...,   0. ,   1. ,   0. ]])

# %% [markdown]
# # 1. XG-BOOST WITHOUT OPTIMIZATION

# %%
# !pip install xgboost
import xgboost as xgb
model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 1, max_depth = 3, n_estimators = 500)
model.fit(X_train, y_train)

# predict the score of the trained model using the testing dataset

result = model.score(X_test, y_test)
# make predictions on the test data
y_predict = model.predict(X_test)

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# Requirement already satisfied: xgboost in c:\users\administrator\appdata\roaming\python\python37\site-packages (1.4.2)
# Requirement already satisfied: numpy in c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in c:\users\administrator\appdata\roaming\python\python37\site-packages (from xgboost) (1.6.3)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# RMSE = 10199.299
# R2 = 0.6567904163148397

# %% [markdown]
# # 2. XG-BOOST WITH GRIDSEARCH

# %%
from sklearn.model_selection import GridSearchCV
parameters_grid = { 'max_depth': [3, 10, 20], 
                   'learning_rate': [0.1, 0.5],
                   'n_estimators': [100, 500],
                   'colsample_bytree': [0.3, 0.7]}

model = xgb.XGBRegressor()

# Note that we used the "neg_mean_squared_error" since GridSearchCV() ranks all the algorithms (estimators) 
# and specifies which one is the best. We are trying to minimize the error.  
xgb_gridsearch = GridSearchCV(estimator = model, 
                              param_grid = parameters_grid, 
                              scoring = 'neg_mean_squared_error',  
                              cv = 5, 
                              verbose = 5)

xgb_gridsearch.fit(X_train, y_train)
y_predict = xgb_gridsearch.predict(X_test)

from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-24583976.234, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-24956446.385, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-176892170.477, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.6s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-60969578.924, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100, score=-39737331.650, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-18750058.380, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-25383111.669, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-161780608.867, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-55079419.612, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500, score=-37220098.462, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-25676268.522, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-35377566.467, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-177605885.900, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-56182343.090, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100, score=-40900521.446, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-25127940.247, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-35466427.091, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-176372029.493, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-55791091.158, total=   3.1s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500, score=-40496754.744, total=   5.3s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100, score=-24776753.321, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100, score=-37865532.216, total=   3.9s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100, score=-181498136.486, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100, score=-57886140.898, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100, score=-40549923.468, total=   3.3s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500, score=-24597405.151, total=   4.7s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500, score=-38131353.300, total=   4.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500, score=-181088952.175, total=   4.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500, score=-57841763.422, total=   4.6s
# [CV] colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500, score=-40639124.007, total=   6.4s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100, score=-34279975.731, total=   0.3s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100, score=-29504671.847, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100, score=-196283080.468, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100, score=-57978001.382, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100, score=-54226604.361, total=   0.2s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500, score=-34110028.832, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500, score=-29426243.417, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500, score=-190176568.903, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500, score=-59035895.591, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500, score=-53266928.929, total=   1.1s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100, score=-31182020.959, total=   0.6s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100, score=-49406957.356, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100, score=-210439189.693, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100, score=-80796888.002, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100, score=-49210163.721, total=   0.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500, score=-31149645.594, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500, score=-49373418.337, total=  12.8s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500, score=-210367182.387, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500, score=-80779104.142, total=   4.4s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500, score=-49197913.289, total=   2.5s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100, score=-42669378.431, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100, score=-60154894.777, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100, score=-217496332.210, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100, score=-87158771.550, total=   0.9s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100, score=-49589282.138, total=   1.0s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500, score=-42669377.465, total=   4.0s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500, score=-60154916.569, total=   3.8s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500, score=-217496361.267, total=   3.7s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500, score=-87158783.418, total=   4.3s
# [CV] colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500, score=-49589291.760, total=   3.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-24344269.154, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-31647042.170, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-171870973.374, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-70353167.014, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, score=-45240645.955, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-19618167.322, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-29392901.427, total=   1.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-159208943.403, total=   1.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-65123683.576, total=   1.9s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500, score=-42152400.749, total=   1.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-24288589.134, total=   1.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-37529590.715, total=   1.0s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-164245516.152, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-71422526.423, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, score=-37711901.173, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-23829534.822, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-37491560.484, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-163418092.041, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-70983552.172, total=   6.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500, score=-37518503.081, total=   5.0s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100, score=-28239025.728, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100, score=-38424894.245, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100, score=-162506010.517, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100, score=-73919934.504, total=   1.1s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100, score=-38694904.260, total=   1.2s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500, score=-28082401.655, total=  10.4s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500, score=-38451944.680, total=   9.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500, score=-162272281.843, total=   9.9s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500, score=-73871106.851, total=   6.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500, score=-38694341.561, total=  12.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100, score=-15538768.148, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100, score=-20044141.421, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100, score=-198782772.521, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100, score=-78017446.904, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100, score=-45132894.298, total=   0.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500, score=-14951288.166, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500, score=-19184209.236, total=   1.8s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500, score=-197293932.862, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500, score=-78301788.602, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500, score=-43844964.186, total=   3.2s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100, score=-18607368.794, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100, score=-39008608.292, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100, score=-164840299.288, total=   2.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100, score=-78243310.822, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100, score=-48458011.384, total=   0.9s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500, score=-18607201.174, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500, score=-39017822.411, total=   6.3s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500, score=-164853445.328, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500, score=-78241451.508, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500, score=-48456277.471, total=   4.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100, score=-17967960.636, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100, score=-44018014.160, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100, score=-174647760.607, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100, score=-86309287.980, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100, score=-44842482.681, total=   1.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500, score=-17967956.530, total=   8.0s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500, score=-44018191.941, total=  11.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500, score=-174647742.226, total=   9.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500, score=-86309163.009, total=   8.7s
# [CV] colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500
# [CV]  colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500, score=-44842501.923, total=   9.3s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  5.2min finished
# RMSE = 5326.116
# R2 = 0.9064077253706981

# %% [markdown]
# # 3. XG-BOOST WITH RANDOMSEARCH

# %%
from sklearn.model_selection import RandomizedSearchCV

# Define the grid of hyperparameters to search

# you can choose which booster you'd like to choose: 
# Two options are available: gbtree, gblinear
# gbtree uses tree based models while gblinear uses linear functions

grid = {
    'n_estimators': [100, 500],
    'max_depth': [3, 10, 20],
    'learning_rate': [0.1, 0.5], 
    'colsample_bytree': [0.3, 0.7]}


import xgboost as xgb
model = xgb.XGBRegressor()

# Set up the random search 
random_cv = RandomizedSearchCV(estimator = model,
                               param_distributions = grid,
                               cv = 5, 
                               n_iter = 100,
                               scoring = 'neg_mean_absolute_error',
                               verbose = 5, 
                               return_train_score = True)
random_cv.fit(X_train, y_train)

random_cv.best_estimator_
y_predict = random_cv.predict(X_test)


from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_search.py:282: UserWarning:
#
# The total space of parameters 24 is smaller than n_iter=100. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-2654.485, test=-3540.728), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-2407.526, test=-3728.049), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-2294.669, test=-5399.227), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-2405.746, test=-4495.576), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-2320.936, test=-4616.259), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-1102.788, test=-2991.498), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-980.757, test=-3581.266), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-995.300, test=-4985.094), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-1053.384, test=-4016.325), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.3, score=(train=-1009.468, test=-4445.871), total=   6.4s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-312.499, test=-3484.442), total=   0.6s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-286.245, test=-4314.293), total=   0.8s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-318.202, test=-5599.222), total=   0.6s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-266.840, test=-4824.771), total=   0.6s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-291.626, test=-4523.410), total=   0.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-20.034, test=-3469.352), total=  13.8s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-22.595, test=-4302.237), total=   2.8s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-23.881, test=-5553.068), total=   2.4s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-16.363, test=-4807.363), total=   3.6s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.3, score=(train=-16.890, test=-4498.426), total=   2.5s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-70.135, test=-3508.303), total=   0.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-67.386, test=-4479.006), total=   0.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-68.286, test=-5731.166), total=   0.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-61.777, test=-5009.061), total=   0.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-59.268, test=-4542.188), total=   1.1s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-0.011, test=-3508.122), total=   6.7s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-0.015, test=-4489.453), total=   7.9s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-0.022, test=-5723.004), total=   4.7s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-0.012, test=-5009.163), total=   5.0s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.3, score=(train=-0.013, test=-4548.592), total=   9.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-1092.280, test=-4102.675), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-1033.595, test=-3830.312), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-1045.111, test=-5644.444), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-959.190, test=-4616.232), total=   0.2s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-968.663, test=-5038.288), total=   0.2s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-87.694, test=-4081.169), total=   1.1s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-81.356, test=-3796.591), total=   2.0s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-95.612, test=-5584.850), total=   1.2s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-72.040, test=-4729.659), total=   3.2s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.3, score=(train=-88.582, test=-4973.562), total=   5.3s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-18.786, test=-3502.729), total=   0.6s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-20.060, test=-4575.812), total=   0.5s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-26.137, test=-6222.859), total=   0.5s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-26.449, test=-6075.103), total=   0.5s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-13.302, test=-5140.835), total=   0.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-3500.536), total=   2.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-4574.010), total=   2.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.002, test=-6222.208), total=   2.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.002, test=-6072.631), total=   2.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-5140.069), total=   6.0s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-4299.887), total=   1.0s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.002, test=-4962.666), total=   2.5s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.002, test=-6342.169), total=   2.0s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.002, test=-6215.817), total=   0.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-5172.622), total=   0.9s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.000, test=-4299.887), total=   4.1s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-4962.668), total=   3.9s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.000, test=-6342.171), total=   7.1s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-6215.816), total=   6.2s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.3, score=(train=-0.001, test=-5172.623), total=   3.8s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-2523.444, test=-3080.802), total=   0.7s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-2286.424, test=-4032.840), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-2199.800, test=-5479.771), total=   0.5s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-2378.387, test=-4560.370), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-2273.681, test=-4834.821), total=   0.4s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-1027.519, test=-2818.490), total=   1.8s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-980.223, test=-3798.756), total=   1.7s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-944.247, test=-4981.534), total=   2.2s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-1091.837, test=-4158.216), total=   1.8s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=0.7, score=(train=-1068.195, test=-4653.709), total=   2.4s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-263.616, test=-3334.542), total=   1.2s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-230.688, test=-4322.083), total=   0.8s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-206.431, test=-5460.282), total=   1.2s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-192.544, test=-4622.931), total=   0.9s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-191.862, test=-4344.174), total=   0.9s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-13.327, test=-3312.485), total=   5.1s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-16.118, test=-4316.274), total=   5.5s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-9.954, test=-5399.339), total=   5.2s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-9.755, test=-4600.925), total=   5.0s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.1, colsample_bytree=0.7, score=(train=-9.016, test=-4349.379), total=   7.3s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-31.727, test=-3586.206), total=   1.6s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-38.548, test=-4475.685), total=   1.6s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-35.247, test=-5687.707), total=   1.6s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-28.319, test=-4859.823), total=   1.6s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-28.903, test=-4343.360), total=   1.8s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-0.013, test=-3579.155), total=  11.3s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-0.013, test=-4474.330), total=  10.7s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-0.013, test=-5678.476), total=   9.8s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-0.014, test=-4862.072), total=  10.9s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.1, colsample_bytree=0.7, score=(train=-0.014, test=-4346.695), total=   8.9s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-821.822, test=-2846.792), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-784.486, test=-3313.309), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-880.789, test=-5519.089), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-822.291, test=-4713.740), total=   0.4s
# [CV] n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-867.949, test=-4809.210), total=   0.4s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-57.042, test=-2810.117), total=   1.8s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-71.216, test=-3236.981), total=   1.8s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-69.892, test=-5415.697), total=   2.0s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-49.934, test=-4692.171), total=   1.8s
# [CV] n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=3, learning_rate=0.5, colsample_bytree=0.7, score=(train=-80.558, test=-4704.392), total=   1.8s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-5.023, test=-3305.852), total=   1.1s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-7.710, test=-4449.352), total=   0.9s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-16.854, test=-5220.162), total=   1.0s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-12.883, test=-4581.408), total=   0.9s
# [CV] n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-7.834, test=-5073.190), total=   1.0s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-3305.874), total=   4.7s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.003, test=-4450.059), total=   5.3s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-5220.096), total=   4.9s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-4580.665), total=   4.7s
# [CV] n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=10, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-5073.218), total=   5.1s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-3211.666), total=   2.0s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-4672.096), total=   1.8s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.002, test=-5809.375), total=   1.8s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.003, test=-5107.345), total=   1.9s
# [CV] n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=100, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-5085.860), total=   1.8s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-3211.667), total=   9.4s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-4672.108), total=   8.5s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-5809.374), total=   8.6s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-5107.332), total=   8.4s
# [CV] n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7
# [CV]  n_estimators=500, max_depth=20, learning_rate=0.5, colsample_bytree=0.7, score=(train=-0.001, test=-5085.862), total=   8.4s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  5.7min finished
# RMSE = 5326.116
# R2 = 0.9064077253706981

# %% [markdown]
# # PRACTICE OPPORTUNITIES SOLUTION

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 SOLUTION:**
# - **Calculate the average, minimum and maximum chances of admission using two different techniques**

# %%
df.describe()

# %%
df.max()

# %%
df.min()

# %%
df.mean()

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
# - **Modify the SOP column to make the bubble size variations more prominent**

# %%
df = pd.read_csv('university_admission.csv')

# %%
# Let's square the SOP column
df['SOP'] = df['SOP'] ** 2

# Let's add a fourth variable "SOP" as the size 
fig = px.scatter(df, x = "GRE Score", y = "Chance of Admit", color = "University Rating", size= 'SOP')
fig.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 SOLUTION:**
# - **Retrain the model with less 'max_depth'**
# - **Comment on the results**

# %%
# Train an XGBoost regressor model 

import xgboost as xgb

model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 1, max_depth = 3, n_estimators = 500)

model.fit(X_train, y_train)
